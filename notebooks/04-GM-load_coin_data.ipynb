# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %load_ext autoreload
# %autoreload 2

from crypto_frontier import efficient_frontier
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pd.read_csv("../crypto_frontier/data/coin_data.csv")
# Out:
#         1INCH       AAVE       ACH       ADA     AERGO       AGLD      AIOZ  \
# 0         NaN        NaN       NaN       NaN       NaN        NaN       NaN
# 1         NaN        NaN       NaN       NaN       NaN        NaN       NaN
# 2         NaN   9.362074       NaN       NaN       NaN        NaN       NaN
# 3         NaN  21.839974       NaN       NaN       NaN        NaN       NaN
# 4         NaN   4.865380       NaN       NaN       NaN        NaN       NaN
# ..        ...        ...       ...       ...       ...        ...       ...
# 452  3.884058  32.777016  4.900000  1.838550  7.856598  -1.713307  2.192243
# 453  2.566964   0.341174 -3.458443 -0.025191  5.127298  22.661243  5.321782
# 454 -3.427639  -7.390838 -3.834937 -4.107173 -3.901783  -0.473709 -3.956130
# 455  5.859155  18.241546  2.712706  2.075852  1.540077 -11.803903  3.344209
# 456  5.481639   0.473934 -1.448399 -0.566329  0.620476  -7.987048 -5.722178
#
# ...
