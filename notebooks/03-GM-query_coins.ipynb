# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %load_ext autoreload
# %autoreload 2

from crypto_frontier import efficient_frontier
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = efficient_frontier.load_fund_data(path="../crypto_frontier/data/Funds.csv")
df.head()
# Out:
#   Unnamed: 0 Dunamis Trading Fund Lemvi Crypto AMC  \
# 0     Dec-19               -0.04%              NaN
# 1     Jan-20                1.51%            7.03%
# 2     Feb-20                3.69%            6.68%
# 3     Mar-20                2.46%            4.56%
# 4     Apr-20                1.05%            5.45%
#
#   Nickel Digital Asset Arbitrage SP - Institutional SwissRex Crypto Fund  \
# 0                                             0.34%              -11.56%
# 1                                             0.81%               39.00%
# 2                                             1.32%               19.60%
# 3                                             0.09%              -14.32%
# 4                                             0.74%               30.77%
#
#   Cambrian Systematic Strategies LP Postera Fund - Crypto I -EUR  \
# 0                            -3.79%                       -4.95%
# 1                            20.36%                       42.87%
# ...

# %%
df = efficient_frontier.download_data()
df
# Out:
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'ADA-USD' found at the CoinBase Pro API, continuing to extraction.
# Provisional Start: 2021-01-01T00:00:00
# Provisional End: 2021-10-28T00:00:00
# Data for chunk 1 of 2 extracted
# Provisional Start: 2021-10-28T00:00:00
# Provisional End: 2022-08-24T00:00:00
# Data for chunk 2 of 2 extracted
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'ETH-USD' found at the CoinBase Pro API, continuing to extraction.
# Provisional Start: 2021-01-01T00:00:00
# Provisional End: 2021-10-28T00:00:00
# Data for chunk 1 of 2 extracted
# Provisional Start: 2021-10-28T00:00:00
# Provisional End: 2022-08-24T00:00:00
# Data for chunk 2 of 2 extracted
#           ADA        ETH
# ...

# %%
df.mean().to_numpy()
# Out:
# array([0.14694115, 0.47534117])

# %%
df
# Out:
#           ADA        ETH
# 0         NaN        NaN
# 1         NaN  26.459435
# 2         NaN   6.317572
# 3         NaN   5.885570
# 4         NaN   9.811276
# ..        ...        ...
# 451  1.838550   2.016512
# 452 -0.025191  -0.441837
# 453 -4.107173  -3.059043
# 454  2.075852   5.281626
# 455 -1.012528   0.081007
#
# [456 rows x 2 columns]

# %%
import requests
url = "https://api.pro.coinbase.com/products"
headers = {"Accept": "application/json"}
response = requests.request("GET", url, headers=headers).json()
# Out:
# {'id': 'ADA-USD',
#  'base_currency': 'ADA',
#  'quote_currency': 'USD',
#  'base_min_size': '0.5',
#  'base_max_size': '3600000',
#  'quote_increment': '0.0001',
#  'base_increment': '0.01',
#  'display_name': 'ADA/USD',
#  'min_market_funds': '1',
#  'max_market_funds': '5000000',
#  'margin_enabled': False,
#  'fx_stablecoin': False,
#  'max_slippage_percentage': '0.03000000',
#  'post_only': False,
#  'limit_only': False,
#  'cancel_only': False,
#  'trading_disabled': False,
#  'status': 'online',
#  'status_message': '',
#  'auction_mode': False}

# %%
base_currencies = []
quote_currencies = []
for coin_data in response:
    if coin_data["quote_currency"] == "USD":
        base_currencies.append(coin_data["base_currency"])

# %%
base_currencies
# Out:
# ['BNT',
#  'AGLD',
#  'PLA',
#  'FIL',
#  'FX',
#  'TRIBE',
#  'DAI',
#  'KEEP',
#  'SPELL',
#  'POWR',
#  'MIR',
#  'DASH',
#  'UNFI',
#  'BCH',
#  'INV',
#  'JASMY',
#  'XYO',
#  'YFI',
#  'DNT',
#  'AXS',
#  'COTI',
#  'PAX',
#  'GALA',
#  'XTZ',
#  'ZRX',
#  'BAND',
#  'REP',
#  'RGT',
#  'SOL',
#  'BAT',
#  'ALCX',
#  'AMP',
#  'OGN',
#  'POLS',
#  'BOND',
#  'RAI',
#  'SYN',
#  'WBTC',
#  'ETH',
#  'IMX',
#  'PLU',
#  'AVT',
#  'FARM',
#  'MLN',
#  'KNC',
#  'WLUNA',
#  'GRT',
#  'IOTX',
#  'ARPA',
#  'MASK',
#  'UMA',
#  'UST',
#  'NMR',
#  'RARI',
#  'STX',
#  'FORTH',
#  'AERGO',
#  'ZEN',
#  'RLY',
#  'LINK',
#  'NU',
#  'MUSD',
#  'OMG',
#  'BADGER',
#  'LQTY',
#  'GFI',
#  'TRAC',
#  'CRPT',
#  'LCX',
#  'SKL',
#  'MCO2',
#  'XLM',
#  'ZEC',
#  'DOT',
#  'FIDA',
#  'AIOZ',
#  'GODS',
#  'BTC',
#  'CHZ',
#  'ENS',
#  'TRU',
#  'PERP',
#  'ANKR',
#  'MDT',
#  'MINA',
#  'NKN',
#  'QNT',
#  'BTRST',
#  'MANA',
#  'DIA',
#  'GYEN',
#  'ORN',
#  'ETC',
#  'GLM',
#  'ALGO',
# ...

# %%
len(base_currencies)
# Out:
# 167
